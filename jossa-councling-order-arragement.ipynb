# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('./Book1.csv', sep=";")

# %%
data
# Out:
#      SrNo.                                          Institute  \
# 0        1  Dr. B R Ambedkar National Institute of Technol...
# 1        2  Dr. B R Ambedkar National Institute of Technol...
# 2        3  Dr. B R Ambedkar National Institute of Technol...
# 3        4  Dr. B R Ambedkar National Institute of Technol...
# 4        5  Dr. B R Ambedkar National Institute of Technol...
# ..     ...                                                ...
# 565    566              Gati Shakti Vishwavidyalaya, Vadodara
# 566    567                                       CU Jharkhand
# 567    568                                       CU Jharkhand
# 568    569                                       CU Jharkhand
# 569    570                                       CU Jharkhand
#
#                                                Program
# 0    Textile Technology (4 Years, Bachelor of Techn...
# 1    Civil Engineering (4 Years, Bachelor of Techno...
# ...

# %%
df = pd.read_csv('./Book2.csv',sep=";")

# %%
df
# Out:
#                                             Institute  \
# 0          Indian Institute of Technology Bhubaneswar
# 1          Indian Institute of Technology Bhubaneswar
# 2          Indian Institute of Technology Bhubaneswar
# 3          Indian Institute of Technology Bhubaneswar
# 4          Indian Institute of Technology Bhubaneswar
# ...                                               ...
# 2092  Birla Institute of Technology, Patna Off-Campus
# 2093  Birla Institute of Technology, Patna Off-Campus
# 2094  Birla Institute of Technology, Patna Off-Campus
# 2095  Birla Institute of Technology, Patna Off-Campus
# 2096   Indian Institute of Handloom Technology, Salem
#
#                                   Academic Program Name Quota Seat Type  \
# 0     Civil Engineering (4 Years, Bachelor of Techno...    AI      OPEN
# 1     Civil Engineering (4 Years, Bachelor of Techno...    AI      OPEN
# 2     Civil Engineering and M. Tech. in Structural E...    AI      OPEN
# ...

# %%
df.sort_values(by="Closing Rank")
# Out:
#                                               Institute  \
# 40                Indian Institute of Technology Bombay
# 812            National Institute of Technology Calicut
# 1503  National Institute of Technology, Tiruchirappalli
# 90                 Indian Institute of Technology Delhi
# 1975       School of Planning & Architecture, New Delhi
# ...                                                 ...
# 1213            National Institute of Technology Sikkim
# 1339          National Institute of Technology, Mizoram
# 1198            National Institute of Technology Sikkim
# 1197            National Institute of Technology Sikkim
# 1343          National Institute of Technology, Mizoram
#
#                                   Academic Program Name Quota Seat Type  \
# 40    Computer Science and Engineering (4 Years, Bac...    AI      OPEN
# 812    Architecture (5 Years, Bachelor of Architecture)    HS      OPEN
# 1503   Architecture (5 Years, Bachelor of Architecture)    HS      OPEN
# ...

# %%
# Filter the DataFrame to exclude rows where the 'Gender' column is "Female-only (including Supernumerary)"
drop_df_1 = df[df['Gender'] != "Female-only (including Supernumerary)"]

# %%
drop_df_1
# Out:
#                                             Institute  \
# 0          Indian Institute of Technology Bhubaneswar
# 2          Indian Institute of Technology Bhubaneswar
# 4          Indian Institute of Technology Bhubaneswar
# 6          Indian Institute of Technology Bhubaneswar
# 8          Indian Institute of Technology Bhubaneswar
# ...                                               ...
# 2092  Birla Institute of Technology, Patna Off-Campus
# 2093  Birla Institute of Technology, Patna Off-Campus
# 2094  Birla Institute of Technology, Patna Off-Campus
# 2095  Birla Institute of Technology, Patna Off-Campus
# 2096   Indian Institute of Handloom Technology, Salem
#
#                                   Academic Program Name Quota Seat Type  \
# 0     Civil Engineering (4 Years, Bachelor of Techno...    AI      OPEN
# 2     Civil Engineering and M. Tech. in Structural E...    AI      OPEN
# 4     Civil Engineering and M.Tech in Transportation...    AI      OPEN
# ...

# %%
drop_df_1 = drop_df_1[~drop_df_1.Institute.str.startswith("Indian Institute of Technology")]
drop_df_1.to_excel("drop1-2.xlsx", index=False)
# drop_df_1.to_excel("all_Closing_Rank_drop1-2.xlsx", index=False)
drop_df_1
# Out:
#                                               Institute  \
# 602   Dr. B R Ambedkar National Institute of Technol...
# 604   Dr. B R Ambedkar National Institute of Technol...
# 606   Dr. B R Ambedkar National Institute of Technol...
# 608   Dr. B R Ambedkar National Institute of Technol...
# 610   Dr. B R Ambedkar National Institute of Technol...
# ...                                                 ...
# 2092    Birla Institute of Technology, Patna Off-Campus
# 2093    Birla Institute of Technology, Patna Off-Campus
# 2094    Birla Institute of Technology, Patna Off-Campus
# 2095    Birla Institute of Technology, Patna Off-Campus
# 2096     Indian Institute of Handloom Technology, Salem
#
#                                   Academic Program Name Quota Seat Type  \
# 602    Bio Technology (4 Years, Bachelor of Technology)    HS      OPEN
# 604    Bio Technology (4 Years, Bachelor of Technology)    OS      OPEN
# 606   Chemical Engineering (4 Years, Bachelor of Tec...    HS      OPEN
# ...

# %%
branch_list =drop_df_1['Academic Program Name'].value_counts()

# %%
branch_list =drop_df_1['Academic Program Name'].value_counts()
branch_set = list()
for program_name,count in branch_list.items():
    data2 = drop_df_1[drop_df_1['Academic Program Name'] == program_name]
    data1 = data2['Academic Program Name']
    data1 = set(data1)
    data1 = list(data1)
    # print(data1[0])
    branch_set.append(list(data1)[0])
    # print(data1)
    # data1.to_excel(f"{program_name}{count}.xlsx", index=False)


# for program in branch_set:
#     data3 = drop_df_1[drop_df_1['Academic Program Name'] == program]
#     print(f"Program: {program}")
#     print(data3)
#     print()  

    
print(branch_set)
# Out:
# ['Computer Science and Engineering (4 Years, Bachelor of Technology)', 'Electronics and Communication Engineering (4 Years, Bachelor of Technology)', 'Mechanical Engineering (4 Years, Bachelor of Technology)', 'Civil Engineering (4 Years, Bachelor of Technology)', 'Electrical Engineering (4 Years, Bachelor of Technology)', 'Chemical Engineering (4 Years, Bachelor of Technology)', 'Electrical and Electronics Engineering (4 Years, Bachelor of Technology)', 'Architecture (5 Years, Bachelor of Architecture)', 'Metallurgical and Materials Engineering (4 Years, Bachelor of Technology)', 'Information Technology (4 Years, Bachelor of Technology)', 'Bio Technology (4 Years, Bachelor of Technology)', 'Production and Industrial Engineering (4 Years, Bachelor of Technology)', 'Mining Engineering (4 Years, Bachelor of Technology)', 'Mathematics and Computing (4 Years, Bachelor of Technology)', 'Chemistry (5 Years, Integrated Master of Science)', 'Physics (5 Years, Integrated Master of Science)', 
# ...

# %%
# data = data2.to_excel(f"{program_name}{count}.xlsx", index=False)
# count = 0
# for program in branch_set:
#     data3 = drop_df_1[drop_df_1['Academic Program Name']==program]
#     data3 =data3.sort_values(by='Closing Rank')
#     # print(data3)
#     filename = program + ".xlsx"
#     count = count + 1
#     # data3.to_excel(filename, index=False)
#     data3.to_excel(f"{program}.xlsx",index=False)
#     print(count)

import os
# import pandas as pd

# Assuming drop_df_1 is already defined
branch_set = drop_df_1['Academic Program Name'].unique()
count = 0

for program in branch_set:
    data3 = drop_df_1[drop_df_1['Academic Program Name'] == program]
    print(f"Program: {program}")
    print(data3)
    print()
    
    # Replace characters that are not allowed in filenames
    safe_program_name = program.replace("/", "-").replace(":", "-").replace("*", "-").replace("?", "-").replace('"', '-').replace("<", "-").replace(">", "-").replace("|", "-")
    
    # Create the directory if it doesn't exist
    directory = os.path.dirname(safe_program_name)
    if not os.path.exists(directory) and directory != '':
        os.makedirs(directory)
    
    # Save the Excel file
    filename = f"{safe_program_name}.xlsx"
    # data3.to_excel(filename, index=False)
    count += 1
    print(count)

# for program in branch_set:
#     data3 = drop_df_1[drop_df_1['Academic Program Name'] == program]
#     print(f"Program: {program}")
#     print(data3)
#     print()  
# print(count)
# Out:
# Program: Bio Technology (4 Years, Bachelor of Technology)
#                                               Institute  \
# 602   Dr. B R Ambedkar National Institute of Technol...
# 604   Dr. B R Ambedkar National Institute of Technol...
# 729   Motilal Nehru National Institute of Technology...
# 731   Motilal Nehru National Institute of Technology...
# 815            National Institute of Technology Calicut
# 817            National Institute of Technology Calicut
# 879           National Institute of Technology Durgapur
# 881           National Institute of Technology Durgapur
# 1157            National Institute of Technology Raipur
# 1159            National Institute of Technology Raipur
# 1354         National Institute of Technology, Rourkela
# 1356         National Institute of Technology, Rourkela
# 1562         National Institute of Technology, Warangal
# 1564         National Institute of Technology, Warangal
# 1678   National Institute of Technology, Andhra Pradesh
# ...

# %%
drop_df_2 = drop_df_1[(drop_df_1.Quota  != "HS")]
drop_df_2
# or (drop_df_1.Institute  == ['Maulana Azad National Institute of Technology Bhopal', 'Indian Institute of Information Technology Bhopal']
# Out:
#                                               Institute  \
# 604   Dr. B R Ambedkar National Institute of Technol...
# 608   Dr. B R Ambedkar National Institute of Technol...
# 612   Dr. B R Ambedkar National Institute of Technol...
# 616   Dr. B R Ambedkar National Institute of Technol...
# 620   Dr. B R Ambedkar National Institute of Technol...
# ...                                                 ...
# 2088    Birla Institute of Technology, Patna Off-Campus
# 2090    Birla Institute of Technology, Patna Off-Campus
# 2092    Birla Institute of Technology, Patna Off-Campus
# 2094    Birla Institute of Technology, Patna Off-Campus
# 2096     Indian Institute of Handloom Technology, Salem
#
#                                   Academic Program Name Quota Seat Type  \
# 604    Bio Technology (4 Years, Bachelor of Technology)    OS      OPEN
# 608   Chemical Engineering (4 Years, Bachelor of Tec...    OS      OPEN
# 612   Civil Engineering (4 Years, Bachelor of Techno...    OS      OPEN
# ...

# %%
# drop_df_3 = drop_df_2[drop_df_2.Institute != (drop_df_2.Institute[:30] != "Indian Institute of Technology")]
drop_df_3 = drop_df_2[~drop_df_2.Institute.str.startswith("Indian Institute of Technology")]

# %%
drop_df_3
# Out:
#                                               Institute  \
# 604   Dr. B R Ambedkar National Institute of Technol...
# 608   Dr. B R Ambedkar National Institute of Technol...
# 612   Dr. B R Ambedkar National Institute of Technol...
# 616   Dr. B R Ambedkar National Institute of Technol...
# 620   Dr. B R Ambedkar National Institute of Technol...
# ...                                                 ...
# 2088    Birla Institute of Technology, Patna Off-Campus
# 2090    Birla Institute of Technology, Patna Off-Campus
# 2092    Birla Institute of Technology, Patna Off-Campus
# 2094    Birla Institute of Technology, Patna Off-Campus
# 2096     Indian Institute of Handloom Technology, Salem
#
#                                   Academic Program Name Quota Seat Type  \
# 604    Bio Technology (4 Years, Bachelor of Technology)    OS      OPEN
# 608   Chemical Engineering (4 Years, Bachelor of Tec...    OS      OPEN
# 612   Civil Engineering (4 Years, Bachelor of Techno...    OS      OPEN
# ...

# %%
drop_df_3 = drop_df_3.sort_values(by="Opening Rank")
drop_df_3.to_excel("all_Closing RankOpening Rank.xlsx", index=False)

# %%
# drop_df_3.to_excel("all_1.xlsx")  
drop_df_3 = drop_df_3.sort_values(by="Closing Rank")
drop_df_3.to_excel("all_Closing Rank.xlsx", index=False)
